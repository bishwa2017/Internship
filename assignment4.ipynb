# %%
# !pip install bs4
# !pip install requests
# !pip install selenium
# !pip install lxml

# %%
from bs4 import BeautifulSoup
import requests
import lxml
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Question 1

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
import pandas as pd
 
table = pd.read_html("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos",attrs={'class':'wikitable sortable'})[0] 
print(table)
# Out:
#                        No.                                       Video name  \
# 0                       1.                           "Baby Shark Dance"[23]
# 1                       2.                                  "Despacito"[25]
# 2                       3.                       "Johny Johny Yes Papa"[26]
# 3                       4.                               "Shape of You"[27]
# 4                       5.                              "See You Again"[28]
# 5                       6.                                  "Bath Song"[31]
# 6                       7.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 7                       8.   "Masha and the Bear – Recipe for Disaster"[33]
# 8                       9.                                "Uptown Funk"[34]
# 9                      10.                "Phonics Song with Two Words"[35]
# 10                     11.                              "Gangnam Style"[36]
# ...

# %%
driver.close()

# %% [markdown]
# # Question 2

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.bcci.tv/")

# %%
dropdown=driver.find_element_by_xpath("//li[@class='footer-navigation__item footer-navigation__item--secondary']")
dropdown.click()

# %%
events_list = driver.find_elements_by_xpath("//div[@class='event-list__list']")
events = []
for i in events_list:
    a = i.get_attribute('innerText')
    print(a)
    events.append(a)
print(events)
# Out:
# October 2021
# Sunday
# 31
# OCTOBER
# 19:30 IST
# T20I
# 2021 ICC MEN'S T20 WORLD CUP
#
# Match 28
# Dubai International Stadium, Dubai
#
# INDIA
#
# v
#
# NEW ZEALAND
#
# MATCH CENTRE
# November 2021
# Wednesday
# 03
# NOVEMBER
# 19:30 IST
# T20I
# 2021 ICC MEN'S T20 WORLD CUP
#
# Match 33
# Zayed Cricket Stadium, Abu Dhabi
#
# INDIA
#
# v
#
# AFGHANISTAN
#
# MATCH CENTRE
# Friday
# 05
# NOVEMBER
# 19:30 IST
# T20I
# 2021 ICC MEN'S T20 WORLD CUP
#
# Match 37
# Dubai International Stadium, Dubai
#
# INDIA
#
# v
#
# SCOTLAND
#
# MATCH CENTRE
# Monday
# 08
# NOVEMBER
# 19:30 IST
# T20I
# 2021 ICC MEN'S T20 WORLD CUP
#
# Match 42
# Dubai International Stadium, Dubai
#
# INDIA
#
# v
#
# NAMIBIA
#
# MATCH CENTRE
# Wednesday
# 17
# NOVEMBER
# T20I
# INDIA V NEW ZEALAND 2021
#
# 1st T20I
# Sawai Mansingh Stadium, Jaipur
#
# INDIA
#
# v
#
# NEW ZEALAND
#
# MATCH CENTRE
# Friday
# 19
# NOVEMBER
# T20I
# INDIA V NEW ZEALAND 2021
#
# 2nd T20I
# JSCA International Stadium Complex, Ranchi
#
# ...

# %%
driver.close()

# %% [markdown]
# # Question 3

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.guru99.com/")

# %%
search_item=driver.find_element_by_xpath('//span[@class="kt-info-svg-icon kt-info-svg-icon-fe_codepen"]')
search_item.click()

# %%
excepsion=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')

# %%
excepsion.click()

# %%
url='https://www.guru99.com/exception-handling-selenium.html'

# %%
table = pd.read_html("https://www.guru99.com/exception-handling-selenium.html",attrs={'class':'table table-striped'})[0] 
print(table)
# Out:
#                          Exception name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
driver.close()

# %% [markdown]
# # Question 4

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.statisticstimes.com/')

# %%
Button=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]')

# %%
Button.click()

# %%
Search_item=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/button/i')

# %%
Search_item.click()

# %%
state_link=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]')

# %%
state_link.click()

# %%
url='https://www.statisticstimes.com/economy/india/indian-states-gdp.php'

# %%
import pandas as pd

# %%
table = pd.read_html("https://www.statisticstimes.com/economy/india/indian-states-gdp.php",attrs={'id':'table_id'})[0] 
print(table)
# Out:
#     Rank                      State GSDP (Cr INR at Current prices)            \
#     Rank                      State                           19-20     18-19
# 0    1.0                Maharashtra                               -   2632792
# 1    2.0                 Tamil Nadu                         1845853   1630208
# 2    3.0              Uttar Pradesh                         1687818   1584764
# 3    4.0                    Gujarat                               -   1502899
# 4    5.0                  Karnataka                         1631977   1493127
# 5    6.0                West Bengal                         1253832   1089898
# 6    7.0                  Rajasthan                         1020989    942586
# 7    8.0             Andhra Pradesh                          972782    862957
# 8    9.0                  Telangana                          969604    861031
# 9   10.0             Madhya Pradesh                          906672    809592
# ...

# %%
driver.close()

# %% [markdown]
# # Question 5

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://github.com/')

# %%
search_item = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/div[2]/div[1]/div/div/form/label')

# %%
search_item.send_keys('Trending Repositories')

# %%
url='https://github.com/search?q=Trending+Repositories'

# %%
driver.get(url)

# %%
repository_list=driver.find_elements_by_xpath('//div[@class="mt-n1 flex-auto"]')
repository=[]
for i in repository_list:
    a = i.get_attribute('innerText')
    print(a)
    repository.append(a)
print(repository)
# Out:
# vitalets/github-trending-repos
#
# Track GitHub trending repositories in your favorite programming language by native GitHub notifications!
#
# github trending trending-repositories
#  2.2k
#  HTML
# Updated on Sep 7, 2020
# mbadry1/Trending-Deep-Learning
#
# Top 100 trending deep learning repositories sorted by the number of stars gained on a specific day.
#
# deep-learning machine-learning deep-neural-networks deep-reinforcement-learning recurrent-neural-networks artificial-intelligence artificial-neural-networks trending-repositories convolutional-neural-networks stargazers-count
#  560
#  Python
# MIT license
# Updated on Feb 2, 2020
# Semigradsky/trending-repositories
#
# ⭐ This is a list of repositories that were trending for a day
#
#  76
#  JavaScript
# Updated on Oct 3, 2018
# laowch/GithubTrends
#
# It's a GitHub Trending repositories Viewer with Material Design.
#
#  639
#  Java
# Apache-2.0 license
# Updated on Jun 10, 2019
# ophobe/trending
#
# ...

# %%
driver.close()

# %% [markdown]
# # Question 6

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.billboard.com/')

# %%
chart=driver.find_elements_by_xpath('span[@class="pill-button__text text--uppercase font--bold padding-l--md padding-r--lg"]')

# %%
full_chart=driver.find_element_by_xpath('/html/body/div[2]/main/div[2]/div/div/div[2]/div[2]/a/span[2]')

# %%
full_chart.click()

# %%
url='https://www.billboard.com/charts/hot-100'

# %%
driver.get(url)

# %%
Song_Name=driver.find_elements_by_xpath('li[@class="chart-list__element display--flex"]')
song_name = []
for i in Song_Name:
    a = i.get_attribute('innerText')
    print(a)
    song_name.append(a)
print(song_name)
# Out:
# []

# %%
driver.close()

# %% [markdown]
# # Question 7

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.naukri.com/')

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys('Data Scientist')

# %%
search_btn = driver.find_element_by_xpath('//div[@class="search-btn"]/button')
search_btn.click()

# %%
job_details_list = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
job_details = []
for i in job_details_list:
    a = i.get_attribute('innerText')
    print(a)
    job_details.append(a)
print(job_details)
# Out:
# Data Scientist
# Data Scientist
# Spark ML Data Scientist
# Geospatial AI Engineer / Geospatial Data Scientists
# Lead Data Scientist
# Senior Data Scientist
# Data Scientist
# Lead Data Scientist
# Hiring For AI Architect / Lead Data Scientist - Bangalore -Iqvia
# Data Scientist
# Lead Data Scientist / Senior Data Scientist
# Senior Data Scientist | Fortune 500 Supermarket Chain
# Senior Data Scientist
# Lead Data Scientist, Presales
# Lead Data Scientist - Machine Learning/ Data Mining
# Data Scientist
# Data Scientist
# Data Scientist
# Data Scientist, Energy modelling
# Senior Data Scientist
# ...

# %%
company_details_list = driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company_details = []
for i in company_details_list:
    a = i.get_attribute('innerText')
    print(a)
    company_details.append(a)
print(company_details)
# Out:
# Think i
# Amazon
# Wipro
# Cyient
# mPokket
# TVS Credit Services
# Alstom Transport India Ltd.
# ZF Friedrichshafen AG
# IQVIA RDS India Pvt Ltd
# Evalueserve
# Emblaze Solutions
# TALENT500 TECH (INDIA) PRIVATE LIMITED
# Santechture
# Moveworks
# Wrackle Technologies Pvt Ltd
# SG Analytics Pvt. Ltd.
# Cyient
# Webhelp
# CEPA
# Easy Recruit
# ['Think i', 'Amazon', 'Wipro', 'Cyient', 'mPokket', 'TVS Credit Services', 'Alstom Transport India Ltd.', 'ZF Friedrichshafen AG', 'IQVIA RDS India Pvt Ltd', 'Evalueserve', 'Emblaze Solutions', 'TALENT500 TECH (INDIA) PRIVATE LIMITED', 'Santechture', 'Moveworks', 'Wrackle Technologies Pvt Ltd', 'SG Analytics Pvt. Ltd.', 'Cyient', 'Webhelp', 'CEPA', 'Easy Recruit']

# %%
job_location_list = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
job_location = []
for i in job_location_list:
    a = i.get_attribute('innerText')
    print(a)
    job_location.append(a)
print(job_location)
# Out:
# Kochi/Cochin, Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)
# Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Mumbai (All Areas)
# (WFH during Covid)
# Hyderabad/Secunderabad
# Kolkata
# Pune, Chennai
# Bangalore/Bengaluru
# Hyderabad
# Bangalore/Bengaluru
# Bangalore/Bengaluru
# (WFH during Covid)
# Mumbai, Pune, Chennai
# Bangalore/Bengaluru
# Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru
# Bangalore/Bengaluru
# Bangalore/Bengaluru
# Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# Hyderabad/Secunderabad
# Gurgaon/Gurugram, Gurgaon
# Remote
# Bangalore/Bengaluru
# ...

# %%
skilled_required_list = driver.find_elements_by_xpath('//ul[@class="tags has-description"]')
skilled_required = []
for i in skilled_required_list:
    a = i.get_attribute('innerText')
    print(a)
    skilled_required.append(a)
print(skilled_required)
# Out:
# Data Science
# Data Mining
# Machine Learning
# Data Science
# Machine Learning
# Python
# Tensorflow
# Artificial Intelligence
# Caffe
# Keras
# Deep Learning
# Pyspark
# Spark
# Machine Learning
# SparkML
# CSV
# Python
# agile
# Communication
# ESRI
# Postgis
# Qgis
# R
# Hive
# Data Scientist
# Data Management
# Big Data
# Time Series
# Neural Networks
# Spark
# Data Science
# Natural Language Processing
# Machine Learning
# Python
# Data Science
# Product Development
# Agile Project Management
# Agile Methodology
# Software Development
# Product Management
# Big Data
# Scrum
# IT Skills
# Python
# Data Science
# Machine Learning
# Cloud
# Project Management
# Azure
# deep learning
# Data Science
# NLP
# Artificial Intelligence
# Natural Language Processing
# Information Extraction
# Information Retrieval
# Machine Learning
# Statistics
# Tensorflow
# Machine Learning
# Python
# Logistic Regression
# Neural Networks
# Keras
# Text Mining
# Support Vector Machine
# Advanced SQL
# ...

# %%
jobs=pd.DataFrame({})
jobs['Designation']=job_details[0:10]
jobs['Company']=company_details[0:10]
jobs['Skills they hire for']=skilled_required[0:10]
jobs['Location']=job_location[0:10]
jobs.head(10)
# Out:
#                                          Designation  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2                            Spark ML Data Scientist
# 3  Geospatial AI Engineer / Geospatial Data Scien...
# 4                                Lead Data Scientist
# 5                              Senior Data Scientist
# 6                                     Data Scientist
# 7                                Lead Data Scientist
# 8  Hiring For AI Architect / Lead Data Scientist ...
# 9                                     Data Scientist
#
#                        Company  \
# 0                      Think i
# 1                       Amazon
# 2                        Wipro
# 3                       Cyient
# 4                      mPokket
# 5          TVS Credit Services
# 6  Alstom Transport India Ltd.
# 7        ZF Friedrichshafen AG
# 8      IQVIA RDS India Pvt Ltd
# 9                  Evalueserve
#
# ...

# %%
driver.close()

# %% [markdown]
# # Question 8

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
import pandas as pd

# %%
table_head=driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/thead')
header=[]
for i in table_head:
    a = i.get_attribute('innerText')
    print(a)
    header.append(a)
print(header)
# Out:
# Rank
#
# Title
#
# Author
#
# Volume Sales
#
# Publisher
#
# Genre
#
#
# ['Rank\n\t\nTitle\n\t\nAuthor\n\t\nVolume Sales\n\t\nPublisher\n\t\nGenre\n\n']

# %%
table_body=driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody')
body=[]
for i in table_body:
    a = i.get_attribute('innerText')
    print(a)
    body.append(a)
print(body)
# Out:
# 1	Da Vinci Code,The	Brown, Dan	5,094,805	Transworld	Crime, Thriller & Adventure
# 2	Harry Potter and the Deathly Hallows	Rowling, J.K.	4,475,152	Bloomsbury	Children's Fiction
# 3	Harry Potter and the Philosopher's Stone	Rowling, J.K.	4,200,654	Bloomsbury	Children's Fiction
# 4	Harry Potter and the Order of the Phoenix	Rowling, J.K.	4,179,479	Bloomsbury	Children's Fiction
# 5	Fifty Shades of Grey	James, E. L.	3,758,936	Random House	Romance & Sagas
# 6	Harry Potter and the Goblet of Fire	Rowling, J.K.	3,583,215	Bloomsbury	Children's Fiction
# 7	Harry Potter and the Chamber of Secrets	Rowling, J.K.	3,484,047	Bloomsbury	Children's Fiction
# 8	Harry Potter and the Prisoner of Azkaban	Rowling, J.K.	3,377,906	Bloomsbury	Children's Fiction
# 9	Angels and Demons	Brown, Dan	3,193,946	Transworld	Crime, Thriller & Adventure
# 10	Harry Potter and the Half-blood Prince:Children's Edition	Rowling, J.K.	2,950,264	Bloomsbury	Children's Fiction
# ...

# %%
table_footer=driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tfoot')
footer=[]
for i in table_footer:
    a = i.get_attribute('innerText')
    print(a)
    footer.append(a)
print(footer)
# Out:
# SOURCE: NIELSEN BOOK SCAN
#
#
#
# ['SOURCE: NIELSEN BOOK SCAN\n\n\n']

# %% [markdown]
# # Question 9

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
from bs4 import BeautifulSoup
import requests
import re
import numpy as np

# %%
url="https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
scrapped_shows=driver.find_elements_by_xpath('//h3[@class="lister-item-header"]')
shows=[]
for i in scrapped_shows:
    a = i.get_attribute('innerText')
    print(a)
    shows.append(a)
print(shows)
# Out:
# 1. Game of Thrones (2011–2019)
# 2. Stranger Things (2016– )
# 3. The Walking Dead (2010–2022)
# 4. 13 Reasons Why (2017–2020)
# 5. The 100 (2014–2020)
# 6. Orange Is the New Black (2013–2019)
# 7. Riverdale (2017– )
# 8. Grey's Anatomy (2005– )
# 9. The Flash (2014– )
# 10. Arrow (2012–2020)
# 11. Money Heist (2017–2021)
# 12. The Big Bang Theory (2007–2019)
# 13. Black Mirror (2011– )
# 14. Sherlock (2010–2017)
# 15. Vikings (2013–2020)
# 16. Pretty Little Liars (2010–2017)
# 17. The Vampire Diaries (2009–2017)
# 18. American Horror Story (2011– )
# 19. Breaking Bad (2008–2013)
# 20. Lucifer (2016–2021)
# 21. Supernatural (2005–2020)
# 22. Prison Break (2005–2017)
# 23. How to Get Away with Murder (2014–2020)
# 24. Teen Wolf (2011–2017)
# 25. The Simpsons (1989– )
# 26. Once Upon a Time (2011–2018)
# 27. Narcos (2015–2017)
# 28. Daredevil (2015–2018)
# 29. Friends (1994–2004)
# 30. How I Met Your Mother (2005–2014)
# 31. Suits (2011–2019)
# 32. Mr. Robot (2015–2019)
# ...

# %%
scrapped_year=driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
year=[]
for i in scrapped_year:
    a = i.get_attribute('innerText')
    print(a)
    year.append(a)
print(year)
# Out:
# (2011–2019)
# (2016– )
# (2010–2022)
# (2017–2020)
# (2014–2020)
# (2013–2019)
# (2017– )
# (2005– )
# (2014– )
# (2012–2020)
# (2017–2021)
# (2007–2019)
# (2011– )
# (2010–2017)
# (2013–2020)
# (2010–2017)
# (2009–2017)
# (2011– )
# (2008–2013)
# (2016–2021)
# (2005–2020)
# (2005–2017)
# (2014–2020)
# (2011–2017)
# (1989– )
# (2011–2018)
# (2015–2017)
# (2015–2018)
# (1994–2004)
# (2005–2014)
# (2011–2019)
# (2015–2019)
# (2013–2018)
# (2015–2021)
# (2007–2012)
# (2015–2018)
# (2014–2019)
# (2016– )
# (2015–2019)
# (2009–2020)
# (2013– )
# (2016–2019)
# (2017–2019)
# (2013–2018)
# (2017–2020)
# (2018– )
# (2019– )
# (2011–2021)
# (2011–2018)
# (2013–2020)
# (2018– )
# (2006–2013)
# (2015– )
# (1999– )
# (2013– )
# (2004–2010)
# (2014– )
# (2004–2012)
# (2015–2018)
# (2013–2017)
# (2011–2020)
# (2015–2020)
# (2016– )
# (2017– )
# (2018–2020)
# (2017– )
# (2014–2019)
# (2009–2015)
# (1997– )
# (2013–2021)
# (2013–2015)
# (2019– )
# (2014–2019)
# (2016–2019)
# (2004–2012)
# ...

# %%
scrapped_genere=driver.find_elements_by_xpath('//span[@class="genre"]')
genere=[]
for i in scrapped_genere:
    a = i.get_attribute('innerText')
    print(a)
    genere.append(a)
print(genere)
# Out:
# Action, Adventure, Drama
# Drama, Fantasy, Horror
# Drama, Horror, Thriller
# Drama, Mystery, Thriller
# Drama, Mystery, Sci-Fi
# Comedy, Crime, Drama
# Crime, Drama, Mystery
# Drama, Romance
# Action, Adventure, Drama
# Action, Adventure, Crime
# Action, Crime, Drama
# Comedy, Romance
# Drama, Sci-Fi, Thriller
# Crime, Drama, Mystery
# Action, Adventure, Drama
# Drama, Mystery, Romance
# Drama, Fantasy, Horror
# Drama, Horror, Thriller
# Crime, Drama, Thriller
# Crime, Drama, Fantasy
# Drama, Fantasy, Horror
# Action, Crime, Drama
# Crime, Drama, Mystery
# Action, Drama, Fantasy
# Animation, Comedy
# Adventure, Fantasy, Romance
# Biography, Crime, Drama
# Action, Crime, Drama
# Comedy, Romance
# Comedy, Romance
# Comedy, Drama
# Crime, Drama, Thriller
# Drama, Fantasy, Horror
# Action, Adventure, Drama
# Drama, Romance
# Drama, Mystery, Sci-Fi
# Action, Crime, Drama
# Drama, Mystery, Sci-Fi
# Action, Crime, Drama
# Comedy, Drama, Romance
# Animation, Adventure, Comedy
# ...

# %%
scrapped_runtime=driver.find_elements_by_xpath('//span[@class="runtime"]')
runtime=[]
for i in scrapped_runtime:
    a = i.get_attribute('innerText')
    print(a)
    runtime.append(a)
print(runtime)
# Out:
# 57 min
# 51 min
# 44 min
# 60 min
# 43 min
# 59 min
# 45 min
# 41 min
# 43 min
# 42 min
# 70 min
# 22 min
# 60 min
# 88 min
# 44 min
# 44 min
# 43 min
# 60 min
# 49 min
# 42 min
# 44 min
# 44 min
# 43 min
# 41 min
# 22 min
# 60 min
# 49 min
# 54 min
# 22 min
# 22 min
# 44 min
# 49 min
# 45 min
# 43 min
# 42 min
# 60 min
# 42 min
# 62 min
# 56 min
# 22 min
# 23 min
# 42 min
# 25 min
# 51 min
# 60 min
# 60 min
# 45 min
# 46 min
# 22 min
# 45 min
# 45 min
# 53 min
# 44 min
# 22 min
# 43 min
# 44 min
# 60 min
# 44 min
# 42 min
# 44 min
# 55 min
# 42 min
# 42 min
# 60 min
# 60 min
# 41 min
# 60 min
# 44 min
# 22 min
# 22 min
# 43 min
# 60 min
# 55 min
# 60 min
# 45 min
# 46 min
# 45 min
# 53 min
# 30 min
# 42 min
# 45 min
# 22 min
# 55 min
# 45 min
# 60 min
# 44 min
# 55 min
# 43 min
# 50 min
# 60 min
# 45 min
# 43 min
# 58 min
# 330 min
# 42 min
# 42 min
# 50 min
# 42 min
# 45 min
# 572 min
# ...

# %%
scrapped_ratings=driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]')
ratings=[]
for i in scrapped_ratings:
    a = i.get_attribute('innerText')
    print(a)
    ratings.append(a)
print(ratings)
# Out:
#  9.2
#  8.7
#  8.2
#  7.5
#  7.6
#  8
#  6.7
#  7.5
#  7.6
#  7.5
#  8.2
#  8.1
#  8.8
#  9.1
#  8.5
#  7.4
#  7.7
#  8
#  9.4
#  8.1
#  8.4
#  8.3
#  8.1
#  7.6
#  8.6
#  7.7
#  8.8
#  8.6
#  8.8
#  8.3
#  8.4
#  8.5
#  8.2
#  6.2
#  7.4
#  8.3
#  7.8
#  8.6
#  7.9
#  8.4
#  9.2
#  6.6
#  8.1
#  8.7
#  8.8
#  7.4
#  8.3
#  8.5
#  7.7
#  7.5
#  7.7
#  8.6
#  6.9
#  8.1
#  8
#  8.3
#  8.8
#  8.7
#  6.7
#  8.3
#  8.3
#  7.4
#  6.8
#  8.4
#  7.5
#  8.1
#  7.8
#  6.7
#  8.7
#  8.4
#  6.6
#  8
#  8.9
#  7.8
#  7.5
#  8.8
#  8.1
#  8.5
#  8.3
#  7.3
#  8.6
#  8.2
#  6.4
#  6.3
#  8.6
#  7.8
#  7.3
#  7.7
#  7.3
#  8.5
#  6.5
#  8.1
#  8.6
#  9.4
#  7.8
#  7.5
#  7.8
#  8.1
#  7.1
#  8.6
# ...

# %%
scrapped_votes=driver.find_elements_by_xpath('//p[@class="text-muted text-small"]')
votes=[]
for i in scrapped_votes:
    a = i.get_attribute('innerText')
    print(a)
    votes.append(a)
print(votes)
# Out:
# TV-MA | 57 min | Action, Adventure, Drama
# Stars: Emilia Clarke, Peter Dinklage, Kit Harington, Lena Headey
# Votes: 1,895,371
# TV-14 | 51 min | Drama, Fantasy, Horror
# Stars: Millie Bobby Brown, Finn Wolfhard, Winona Ryder, David Harbour
# Votes: 926,663
# TV-14 | 44 min | Drama, Horror, Thriller
# Stars: Andrew Lincoln, Norman Reedus, Melissa McBride, Lauren Cohan
# Votes: 910,542
# TV-MA | 60 min | Drama, Mystery, Thriller
# Stars: Dylan Minnette, Katherine Langford, Christian Navarro, Alisha Boe
# Votes: 272,467
# TV-14 | 43 min | Drama, Mystery, Sci-Fi
# Stars: Eliza Taylor, Bob Morley, Marie Avgeropoulos, Isaiah Washington
# Votes: 232,886
# TV-MA | 59 min | Comedy, Crime, Drama
# Stars: Taylor Schilling, Danielle Brooks, Taryn Manning, Emma Myles
# Votes: 288,422
# TV-14 | 45 min | Crime, Drama, Mystery
# Stars: K.J. Apa, Lili Reinhart, Camila Mendes, Cole Sprouse
# Votes: 132,069
# TV-14 | 41 min | Drama, Romance
# ...

# %%
Topshows=pd.DataFrame({})
Topshows['Name']=shows[0:100]
Topshows['Genere']=genere[0:100]
Topshows['Runtime']=runtime[0:100]
Topshows['Ratings']=ratings[0:100]
Topshows.head(100)
# Out:
#                                               Name                    Genere  \
# 0                   1. Game of Thrones (2011–2019)  Action, Adventure, Drama
# 1                      2. Stranger Things (2016– )    Drama, Fantasy, Horror
# 2                  3. The Walking Dead (2010–2022)   Drama, Horror, Thriller
# 3                    4. 13 Reasons Why (2017–2020)  Drama, Mystery, Thriller
# 4                           5. The 100 (2014–2020)    Drama, Mystery, Sci-Fi
# ..                                             ...                       ...
# 95                           96. Reign (2013–2017)            Drama, Fantasy
# 96  97. A Series of Unfortunate Events (2017–2019)  Adventure, Comedy, Drama
# 97                  98. Criminal Minds (2005–2020)     Crime, Drama, Mystery
# 98           99. Scream: The TV Series (2015–2019)      Comedy, Crime, Drama
# 99          100. The Haunting of Hill House (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings
# 0    57 min     9.2
# ...

# %%
driver.close()

# %% [markdown]
# # Question 10

# %%
driver = webdriver.Chrome(r'C:\Users\bisue\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://archive.ics.uci.edu/ml/index.php')

# %%
search_item=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b')

# %%
search_item.click()
